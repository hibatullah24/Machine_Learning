# %% [markdown]
# # Class example1:

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
c = np.random.randint(0, 100, size=100)
f = (9/5) * c + 32

# %%
c.shape, f.shape
# Out:
# ((100,), (100,))

# %%
data = pd.DataFrame({
    "c" : c,
    "f" : f

})

# %%
data
# Out:
#      c      f
# 0   85  185.0
# 1   35   95.0
# 2   33   91.4
# 3   92  197.6
# 4   39  102.2
# ..  ..    ...
# 95  79  174.2
# 96  10   50.0
# 97  63  145.4
# 98  68  154.4
# 99  63  145.4
#
# [100 rows x 2 columns]

# %%
model = LinearRegression()

# %%
model.fit(c.reshape(-1,1), f.reshape(-1,1))
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# it not change even you increase number of columns
# Out:
# (array([[1.8]]), array([32.]))

# %%
#i will add noise to the model is the coef and intercept will change?
for m in [50, 100, 1000, 10000]:
    c = np.random.randint(0, 100, size=m)
    f = (9/5) * c + 32
    f = f + np.random.normal()

    x = c.reshape(-1,1)
    y = f.reshape(-1,1)

    model = LinearRegression()

    model.fit(x,y)
    print(f"m: {model.coef_}, b: {model.intercept_}")
# Out:
# m: [[1.8]], b: [32.7801189]
# m: [[1.8]], b: [31.69265754]
# m: [[1.8]], b: [32.6273273]
# m: [[1.8]], b: [32.38044445]

# %% [markdown]
# # class Example 2

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
X = np.random.randint(0, 100, size=10)
y = np.random.normal() * X + 5 + np.random.randint(0,10) * X
y[6] = y[6] + 10
y[3] = y[3] + -10
y[7] = y[7] + -30

# %%
plt.scatter(X, y, marker="+")

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X.reshape(-1, 1), y.reshape(-1, 1))
# Out:
# LinearRegression()

# %% [markdown]
# LinearRegression()
#
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.
#
# LinearRegression
# ?Documentation for LinearRegressioniFitted
# LinearRegression()

# %%
# give me value between min and max then do test for new 100 features 
new_X = np.linspace(X.min(), X.max(), 100)
y_hat = model.predict(new_X.reshape(-1, 1))

# %%
plt.scatter(X, y, color="red",marker="+")
plt.plot(new_X, y_hat)
